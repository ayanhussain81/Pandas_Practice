# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:ertugrul12345@localhost:3306/application')

# %%
df = pd.read_sql_table('details',engine)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\92336\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# c:\users\92336\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     324         """
# --> 325         return _ConnectionFairy._checkout(self)
#     326
#
# c:\users\92336\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     887         if not fairy:
# --> 888             fairy = _ConnectionRecord.checkout(pool)
#     889
#
# c:\users\92336\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
# ...
